# %% [markdown]
# # Data transformation<hr>

# %% [markdown]
# # Loding previous file(Data_Cleaning)

# %%
# %run Data_Cleaning.ipynb
managed_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# # Converting date to datetime format
# -  convert a date or a column containing date-like strings into datetime objects
# - df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
# - 2025-02-01

# %%
transformed_data=managed_data.copy()
transformed_data["DATE"]=pd.to_datetime(transformed_data["DATE"])
transformed_data.head()
# Out:
#    OD_NO  QTY   PRICE  OD_LINE_NO    SALES       DATE   STATUS  QTR_ID  \
# 0  10107   30   95.70           2  2871.00 2003-02-24  shipped       1
# 1  10121   34   81.35           5  2765.90 2003-05-07  shipped       2
# 2  10134   41   94.74           2  3884.34 2003-07-01  shipped       3
# 3  10145   45   83.26           6  3746.70 2003-08-25  shipped       3
# 4  10159   49  100.00          14  5205.27 2003-10-10  shipped       4
#
#    PRODUCTLINE  COST  ...             PHONE                           ADD1  \
# 0  motorcycles    95  ...        2125557818        897 long airport avenue
# 1  motorcycles    95  ...        26.47.1555             59 rue de l'abbaye
# 2  motorcycles    95  ...  +33 1 46 62 7555  27 rue du colonel pierre avia
# 3  motorcycles    95  ...        6265557265             78934 hillside dr.
# 4  motorcycles    95  ...        6505551386                7734 strong st.
#
#                             ADD2           CITY    STATE POSTALCODE COUNTRY  \
# ...

# %% [markdown]
# # Creating new calculated columns

# %% [markdown]
# changing cost function with total cost i.e cost*qty and same with profit

# %%
transformed_data["COST"] = managed_data["COST"] * transformed_data["QTY"]
transformed_data
# Out:
#       OD_NO  QTY   PRICE  OD_LINE_NO    SALES       DATE    STATUS  QTR_ID  \
# 0     10107   30   95.70           2  2871.00 2003-02-24   shipped       1
# 1     10121   34   81.35           5  2765.90 2003-05-07   shipped       2
# 2     10134   41   94.74           2  3884.34 2003-07-01   shipped       3
# 3     10145   45   83.26           6  3746.70 2003-08-25   shipped       3
# 4     10159   49  100.00          14  5205.27 2003-10-10   shipped       4
# ...     ...  ...     ...         ...      ...        ...       ...     ...
# 2818  10350   20  100.00          15  2244.40 2004-12-02   shipped       4
# 2819  10373   29  100.00           1  3978.51 2005-01-31   shipped       1
# 2820  10386   43  100.00           4  5417.57 2005-03-01  resolved       1
# 2821  10397   34   62.24           1  2116.16 2005-03-28   shipped       1
# 2822  10414   47   65.52           9  3079.44 2005-05-06   on hold       2
#
# ...

# %%
transformed_data["PROFIT"]=transformed_data["SALES"]-transformed_data["COST"]
transformed_data["PROFIT%"]=round((transformed_data["PROFIT"]/transformed_data["PRICE"])*100,2)
transformed_data.head()
# Out:
#    OD_NO  QTY   PRICE  OD_LINE_NO    SALES       DATE   STATUS  QTR_ID  \
# 0  10107   30   95.70           2  2871.00 2003-02-24  shipped       1
# 1  10121   34   81.35           5  2765.90 2003-05-07  shipped       2
# 2  10134   41   94.74           2  3884.34 2003-07-01  shipped       3
# 3  10145   45   83.26           6  3746.70 2003-08-25  shipped       3
# 4  10159   49  100.00          14  5205.27 2003-10-10  shipped       4
#
#    PRODUCTLINE  COST  ...                           ADD2           CITY  \
# 0  motorcycles  2850  ...        897 long airport avenue            nyc
# 1  motorcycles  3230  ...             59 rue de l'abbaye          reims
# 2  motorcycles  3895  ...  27 rue du colonel pierre avia          paris
# 3  motorcycles  4275  ...             78934 hillside dr.       pasadena
# 4  motorcycles  4655  ...                7734 strong st.  san francisco
#
#      STATE POSTALCODE COUNTRY TERRITORY DEALSIZE             NAME  PROFIT  \
# ...

# %% [markdown]
# # TESTING

# %%
s=transformed_data["SALES"].sum()
c=transformed_data["COST"].sum()
p=transformed_data["PROFIT"].sum()
print(s)
print(c)
print(p)
# Out:
# 10032628.85
# 9997342
# 35286.850000000006
